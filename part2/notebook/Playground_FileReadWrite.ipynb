# %% [markdown]
# <a href="https://colab.research.google.com/github/harishkaparwan/GettingStartedWithPython/blob/main/part2/notebook/Playground_FileReadWrite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#rt to read a text file. 
#wt to write a file
#'rb'
#wb
# open('somefile.txt', 'rt', encoding='latin-1') as f:

# Read the entire file as a single string
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/hck.txt', 'rt') as f: 
        data = f.read()
        print(data)

# Iterate over the lines of the file
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/hck.txt', 'rt') as f: 
    for line in f:
        print(line)
       
        
# Redirected print statement
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/hck.txt', 'wt') as f: 
    print("This i smy new", file=f)
    print("This i smy new 4", file=f)
        
# Iterate over the lines of the file
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/hck.txt', 'rt') as f: 
    for line in f:
        print(line)
# Out:
# This i smy new
# This i smy new 3
#
# This i smy new
#
# This i smy new 3
#
# This i smy new
#
# This i smy new 4

# %%
import array
nums = array.array('i', [1, 2, 3, 4]) 
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/hckdata.bin','wb') as f:
        f.write(nums)
        f.close()

# %%
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/hckdata.bin', 'rb') as f: 
    f.readinto(a)
    print(a)
# Out:
# array('i', [1, 2, 3, 4, 0, 0, 0, 0])

# %%
import os
if not os.path.exists('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/hckdata.bin'): 
        print('File already exists!')
else:
    print('File already exists!')
# Out:
# File already exists!

# %%
 # gzip compression
import gzip
with gzip.open('somefile.gz', 'rt') as f:
        text = f.read()
    # bz2 compression
import bz2
with bz2.open('somefile.bz2', 'rt') as f:
text = f.read()
Similarly, to write compressed data, do this:
    # gzip compression
import gzip
with gzip.open('somefile.gz', 'wt') as f:
        f.write(text)
    # bz2 compression
import bz2
with bz2.open('somefile.bz2', 'wt') as f:
f.write(text)

# %%
#Serializing Python Objects
#The most common approach for serializing data is to use the pickle module. To dump an object to a file, you do this:
import pickle
data = ... # Some Python object 
f = open('somefile', 'wb')
pickle.dump(data, f)

#To dump an object to a string use pickle dumps
s = pickle.dumps(data)
#To re-create an object from a byte stream, use either the pickle.load() or pick le.loads() functions. For example:

# Restore from a file
f = open('somefile', 'rb')
data = pickle.load(f)

# Restore from a string
data = pickle.loads(s)

# %%
import csv
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/stocks.csv') as f:
    f_csv = csv.reader(f) 
    headers = next(f_csv) 
    for row in f_csv:
        print(row)
# Out:
# ['MSFT', 'Jan 1 2000', '39.81']
# ['MSFT', 'Feb 1 2000', '36.35']
# ['MSFT', 'Mar 1 2000', '43.22']
# ['MSFT', 'Apr 1 2000', '28.37']
# ['MSFT', 'May 1 2000', '25.45']
# ['MSFT', 'Jun 1 2000', '32.54']
# ['MSFT', 'Jul 1 2000', '28.4']
# ['MSFT', 'Aug 1 2000', '28.4']
# ['MSFT', 'Sep 1 2000', '24.53']
# ['MSFT', 'Oct 1 2000', '28.02']
# ['MSFT', 'Nov 1 2000', '23.34']
# ['MSFT', 'Dec 1 2000', '17.65']
# ['MSFT', 'Jan 1 2001', '24.84']
# ['MSFT', 'Feb 1 2001', '24']
# ['MSFT', 'Mar 1 2001', '22.25']
# ['MSFT', 'Apr 1 2001', '27.56']
# ['MSFT', 'May 1 2001', '28.14']
# ['MSFT', 'Jun 1 2001', '29.7']
# ['MSFT', 'Jul 1 2001', '26.93']
# ['MSFT', 'Aug 1 2001', '23.21']
# ['MSFT', 'Sep 1 2001', '20.82']
# ['MSFT', 'Oct 1 2001', '23.65']
# ['MSFT', 'Nov 1 2001', '26.12']
# ['MSFT', 'Dec 1 2001', '26.95']
# ['MSFT', 'Jan 1 2002', '25.92']
# ['MSFT', 'Feb 1 2002', '23.73']
# ['MSFT', 'Mar 1 2002', '24.53']
# ['MSFT', 'Apr 1 2002', '21.26']
# ['MSFT', 'May 1 2002', '20.71']
# ...

# %%
headers = ['Symbol', 'Price', 'Date', 'Time', 'Change', 'Volume']
rows = [{'Symbol':'AA', 'Price':39.48, 'Date':'6/11/2007',
              'Time':'9:36am', 'Change':-0.18, 'Volume':181800},
            {'Symbol':'AIG', 'Price': 71.38, 'Date':'6/11/2007',
              'Time':'9:36am', 'Change':-0.15, 'Volume': 195500},
            {'Symbol':'AXP', 'Price': 62.58, 'Date':'6/11/2007',
              'Time':'9:36am', 'Change':-0.46, 'Volume': 935000},
            ]
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/stocks1.csv','w') as f: 
        f_csv = csv.DictWriter(f, headers) 
        f_csv.writeheader() 
        f_csv.writerows(rows)

# %%
import json
data = {
       'name' : 'ACME',
       'shares' : 100,
       'price' : 542.23
}
json_str = json.dumps(data)
#print(json_str)

# Writing JSON data
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/data.json', 'w') as f: 
    json.dump(data, f)
# Reading data back
with open('/Users/harishkaparwan/Developer/Github/GettingStartedWithPython/data.json', 'r') as f: 
    data = json.load(f)
    print(data)
# Out:
# {'name': 'ACME', 'shares': 100, 'price': 542.23}
